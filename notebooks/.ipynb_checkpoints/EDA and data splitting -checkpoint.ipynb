# %%
import json
import os
import sys

# %%
import pandas as pd
import numpy as np

# %%
sys.path.append("..")

# %%
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Amazon music dataset

# %%
dataset = []
with open("../data/amazon-digital-music-raw.json", 'r') as file:
    for line in file.readlines():
        dataset.append(json.loads(line))

# %%
dataset[2]
# Out:
# {'overall': 5.0,
#  'verified': True,
#  'reviewTime': '02 11, 2014',
#  'reviewerID': 'A2VAMODP8M77NG',
#  'asin': '3426958910',
#  'style': {'Format:': ' Audio CD'},
#  'reviewerName': 'JTGabq',
#  'reviewText': 'It was great to hear the old stuff again and I like the new stuff too. I recommend it to any Slayer fan.',
#  'summary': 'SLAYER!!!!!!!!!!!!!!!!!!!!!',
#  'unixReviewTime': 1392076800}

# %%
dataset_pd = pd.DataFrame(dataset)

# %%
dataset_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169781 entries, 0 to 169780
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         169781 non-null  float64
#  1   vote            7611 non-null    object
#  2   verified        169781 non-null  bool
#  3   reviewTime      169781 non-null  object
#  4   reviewerID      169781 non-null  object
#  5   asin            169781 non-null  object
#  6   style           157989 non-null  object
#  7   reviewerName    169776 non-null  object
#  8   reviewText      169623 non-null  object
#  9   summary         169745 non-null  object
#  10  unixReviewTime  169781 non-null  int64
#  11  image           182 non-null     object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 14.4+ MB

# %%
dataset_pd.isna().sum()
# Out:
# overall                0
# vote              162170
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style              11792
# reviewerName           5
# reviewText           158
# summary               36
# unixReviewTime         0
# image             169599
# dtype: int64

# %%
dataset_pd = dataset_pd.dropna(subset=["reviewText"])
dataset_pd = dataset_pd.reset_index()

# %%
dataset_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169623 entries, 0 to 169622
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           169623 non-null  int64
#  1   overall         169623 non-null  float64
#  2   vote            7611 non-null    object
#  3   verified        169623 non-null  bool
#  4   reviewTime      169623 non-null  object
#  5   reviewerID      169623 non-null  object
#  6   asin            169623 non-null  object
#  7   style           157835 non-null  object
#  8   reviewerName    169618 non-null  object
#  9   reviewText      169623 non-null  object
#  10  summary         169611 non-null  object
#  11  unixReviewTime  169623 non-null  int64
#  12  image           181 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 15.7+ MB

# %%
dataset_pd.head()
# Out:
#    index  overall vote  verified   reviewTime      reviewerID        asin  \
# 0      0      5.0    3      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1      1      5.0  NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2      2      5.0  NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3      3      4.0    3     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4      4      5.0  NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 3  {'Format:': ' Audio CD'}  john F&#039;n doe
# 4  {'Format:': ' Audio CD'}  melinda a goodman
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# 3  well best of's are a bit poison normally but t...
# 4  What can I say? This is Casting Crowns!!!This ...
#
#                                              summary  unixReviewTime image
# 0                                      Slayer Rules!      1370217600   NaN
# 1                                         Five Stars      1412985600   NaN
# 2                        SLAYER!!!!!!!!!!!!!!!!!!!!!      1392076800   NaN
# 3  slayer greatest hits! you mean everything righ...      1386374400   NaN
# 4                    This is a good, blessing filled      1465689600   NaN

# %%
all_votes = dataset_pd['overall'].unique()

for v in all_votes:
    print(f"percentage of votes for rating {v} : {round(len(dataset_pd[dataset_pd['overall'] == v]) / len(dataset_pd)* 100, 3) } ")
# Out:
# percentage of votes for rating 5.0 : 79.992
# percentage of votes for rating 4.0 : 13.643
# percentage of votes for rating 2.0 : 1.068
# percentage of votes for rating 3.0 : 4.004
# percentage of votes for rating 1.0 : 1.292

# %% [markdown]
# ### Stratifying the samples to get smaller datasets

# %%
stratifier = StratifiedKFold(n_splits= 10 )

# %%
# Create a new column in the DataFrame to store the fold number for each row
dataset_pd['fold'] = -1

# Perform stratified sampling and assign fold numbers to each row
for fold_number, (train_indices, test_indices) in enumerate(stratifier.split(dataset_pd, dataset_pd["overall"])):
    dataset_pd.loc[test_indices, 'fold'] = fold_number

# %%
for fold in dataset_pd['fold'].unique():
    fold_df:pd.DataFrame = dataset_pd[dataset_pd['fold'] == fold]
    
    fold_df.to_json(f"../data/amazon-digital-music-raw-fold-{fold}.json",orient="records", lines = True, )

# %%
fold1 = pd.read_json("../data/amazon-digital-music-raw-fold-1.json", lines=True)

# %%
fold1
# Out:
#        index  overall  vote  verified   reviewTime      reviewerID  \
# 0      16585        5   NaN      True  11 24, 2013    AVP1NL6GYMVR
# 1      16586        5   NaN      True  08 21, 2013  A3NVWWDF437JBD
# 2      16587        5   NaN      True  08 12, 2013  A1NADGMAR6GQW1
# 3      16588        5   NaN      True   08 9, 2013  A21X3U0ELWDPPQ
# 4      16589        5   NaN      True  03 26, 2015  A32VFN0E3238Z0
# ...      ...      ...   ...       ...          ...             ...
# 16958  54526        2   NaN      True  12 24, 2015  A2J1U7GCS0KL7A
# 16959  54532        2   NaN      True   04 5, 2015  A2JMRUN0QULNLI
# 16960  54812        2   NaN      True   11 1, 2013  A3RVBA621G3W6I
# 16961  54839        2   NaN     False  06 10, 2008  A3PCTD8QM1BIXI
# 16962  54841        2   NaN     False  04 19, 2011  A3GP5YP52BD4EX
#
#              asin                      style  \
# 0      B00123M8ZY                       None
# 1      B00123M8ZY                       None
# 2      B00123M8ZY                       None
# 3      B00123M8ZY                       None
# 4      B00123LUXA  {'Format:': ' MP3 Music'}
# ...           ...                        ...
# 16958  B001E9ULJ6  {'Format:': ' MP3 Music'}
# 16959  B001E9ULJ6  {'Format:': ' MP3 Music'}
# 16960  B001ESDIQ0                       None
# 16961  B001ESDIQ0                       None
# 16962  B001ESSLIU                       None
#
#                                      reviewerName  \
# 0                                          RDSWY4
# 1                          Obsessive Cat Disorder
# 2                                      Coolbob425
# 3                                     Don Kennedy
# 4                                   Jerry Colvard
# ...                                           ...
# 16958                                        Cara
# 16959                                    Indy Mog
# 16960  Joseph McGuinness (Ray Ray&#039;s Records)
# 16961                                Derrick Dunn
# 16962                                  Sotiris K.
#
#                                               reviewText  \
# 0      The first time I ever heard this song was as a...
# 1      This is just a gorgeous ballad. Was used in Pl...
# 2      At the age of 66 and widowed I have been going...
# 3      This is a rather old song (1950s) which has be...
# 4                                            love oldies
# ...                                                  ...
# 16958                                   Not my favorite.
# 16959                                       It's alright
# 16960  Tha Carter III Volume 1 Vinyl only has 8 songs...
# 16961  After numerous delays and lots of hype, Lil Wa...
# 16962  This album is not Sepultura album. if you are ...
#
#                               summary  unixReviewTime image  fold
# 0                   Must Have Classic      1385251200  None     1
# 1                           Beautiful      1377043200  None     1
# 2                   CD for Girlfriend      1376265600  None     1
# 3                          First Time      1376006400  None     1
# 4                          Five Stars      1427328000  None     1
# ...                               ...             ...   ...   ...
# 16958                       Two Stars      1450915200  None     1
# 16959                       Two Stars      1428192000  None     1
# 16960   Tha Carter III Volume 1 Vinyl      1383264000  None     1
# 16961  Over Hyped And A Waste Of Time      1213056000  None     1
# 16962                       2,5 stars      1303171200  None     1
#
# [16963 rows x 14 columns]

# %%
all_votes = fold1['overall'].unique()

for v in all_votes:
    print(f"percentage of votes for rating {v} : {round(len(fold1[fold1['overall'] == v]) / len(fold1)* 100, 3) } ")
# Out:
# percentage of votes for rating 5 : 79.992
# percentage of votes for rating 4 : 13.641
# percentage of votes for rating 3 : 4.003
# percentage of votes for rating 1 : 1.297
# percentage of votes for rating 2 : 1.067

# %% [markdown]
# ## News categories dataset
